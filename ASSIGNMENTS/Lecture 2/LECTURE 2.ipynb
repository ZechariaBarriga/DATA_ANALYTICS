# %% [markdown]
# Data: https://archive.ics.uci.edu.
#
# Instruction: Choose a dataset and perform a data storytelling, choose the proper data visualization, do not use words, your graphs must tell a story.

# %%
import pandas as pd
from scipy.io import arff
import matplotlib.pyplot as plt
import seaborn as sns

# Load ARFF file with specified encoding
with open('Raisin_Dataset.arff', 'r', encoding='utf-8') as f:
    data, meta = arff.loadarff(f)

# Convert data to pandas DataFrame
df = pd.DataFrame(data)

# Decode byte strings to regular strings if needed
for column in df.columns:
    if df[column].dtype == 'object':
        df[column] = df[column].str.decode('utf-8')
        
# checkpoint
features = df.columns[:-1]  # Exclude the 'Class' column

df
# Out:
#         Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0    87524.0       442.246011       253.291155      0.819738     90546.0
# 1    75166.0       406.690687       243.032436      0.801805     78789.0
# 2    90856.0       442.267048       266.328318      0.798354     93717.0
# 3    45928.0       286.540559       208.760042      0.684989     47336.0
# 4    79408.0       352.190770       290.827533      0.564011     81463.0
# ..       ...              ...              ...           ...         ...
# 895  83248.0       430.077308       247.838695      0.817263     85839.0
# 896  87350.0       440.735698       259.293149      0.808629     90899.0
# 897  99657.0       431.706981       298.837323      0.721684    106264.0
# 898  93523.0       476.344094       254.176054      0.845739     97653.0
# 899  85609.0       512.081774       215.271976      0.907345     89197.0
#
#        Extent  Perimeter    Class
# 0    0.758651   1184.040  Kecimen
# ...

# %%
# Set the style for the plots
sns.set(style="whitegrid")
# Step 1: Explore the distributions of each morphological feature for both classes of raisins
for feature in features:
    plt.figure(figsize=(10, 6))
    sns.histplot(data=df, x=feature, hue='Class', kde=True, palette='Set2')
    plt.title(f'Distribution of {feature} for Kecimen and Besni raisins')
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.legend(title=feature, labels=['Kecimen', 'Besni'])
    plt.show()

# %%
# Step 2: Investigate relationships between pairs of features using scatter plots
sns.pairplot(df, hue='Class', palette='Set2')
plt.suptitle('Pairplot of Morphological Features for Kecimen and Besni Raisins')
plt.show()

# %%
# Step 3: Compare the overall distributions of features between Kecimen and Besni raisins using box plots
for feature in features:
    plt.figure(figsize=(12, 8))
    sns.boxplot(data=df, x='Class', y=feature, palette='Set2')
    plt.title(f'Boxplot of {feature} for Kecimen and Besni raisins')
    plt.xlabel('Class')
    plt.ylabel(feature)
    plt.show()
# Out:
# C:\Users\barri\AppData\Local\Temp\ipykernel_16432\1154333836.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Class', y=feature, palette='Set2')
# C:\Users\barri\AppData\Local\Temp\ipykernel_16432\1154333836.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Class', y=feature, palette='Set2')
# C:\Users\barri\AppData\Local\Temp\ipykernel_16432\1154333836.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Class', y=feature, palette='Set2')
# ...
