# %% [markdown]
# # Instructions
#
# 1. Choose a dataset from https://archive.ics.uci.edu/datasets.
# 2. Your dataset should be unique to that of your classmate, so be sure to discuss with them, otherwise no points will be given into this assignment.
# 3.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay,classification_report
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
from scipy.io import arff

# Load ARFF file with specified encoding
with open('Raisin_Dataset.arff', 'r', encoding='utf-8') as f:
    data, meta = arff.loadarff(f)

# Convert data to pandas DataFrame
df = pd.DataFrame(data)

# Decode byte strings to regular strings if needed
for column in df.columns:
    if df[column].dtype == 'object':
        df[column] = df[column].str.decode('utf-8')

# Replace categorical values with numerical values
df['Class'] = df['Class'].map({'Kecimen': 0, 'Besni': 1})

# 0 for Kecimen
# 1 for Besni

df
# Out:
#         Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0    87524.0       442.246011       253.291155      0.819738     90546.0
# 1    75166.0       406.690687       243.032436      0.801805     78789.0
# 2    90856.0       442.267048       266.328318      0.798354     93717.0
# 3    45928.0       286.540559       208.760042      0.684989     47336.0
# 4    79408.0       352.190770       290.827533      0.564011     81463.0
# ..       ...              ...              ...           ...         ...
# 895  83248.0       430.077308       247.838695      0.817263     85839.0
# 896  87350.0       440.735698       259.293149      0.808629     90899.0
# 897  99657.0       431.706981       298.837323      0.721684    106264.0
# 898  93523.0       476.344094       254.176054      0.845739     97653.0
# 899  85609.0       512.081774       215.271976      0.907345     89197.0
#
#        Extent  Perimeter  Class
# 0    0.758651   1184.040      0
# 1    0.684130   1121.786      0
# 2    0.637613   1208.575      0
# 3    0.699599    844.162      0
# 4    0.792772   1073.251      0
# ..        ...        ...    ...
# 895  0.668793   1129.072      1
# 896  0.636476   1214.252      1
# 897  0.741099   1292.828      1
# 898  0.658798   1258.548      1
# 899  0.632020   1272.862      1
#
# [900 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             900 non-null    float64
#  1   MajorAxisLength  900 non-null    float64
#  2   MinorAxisLength  900 non-null    float64
#  3   Eccentricity     900 non-null    float64
#  4   ConvexArea       900 non-null    float64
#  5   Extent           900 non-null    float64
#  6   Perimeter        900 non-null    float64
#  7   Class            900 non-null    int64
# dtypes: float64(7), int64(1)
# memory usage: 56.4 KB

# %%
df.isna().sum()
# Out:
# Area               0
# MajorAxisLength    0
# MinorAxisLength    0
# Eccentricity       0
# ConvexArea         0
# Extent             0
# Perimeter          0
# Class              0
# dtype: int64

# %%
df = df.dropna()

# %% [markdown]
# ## Visualization

# %%
sns.scatterplot(x='Area',y='Class',data=df,hue='Class',palette='Dark2')
# Out:
# <Axes: xlabel='Area', ylabel='Class'>

# %%
sns.pairplot(df,hue='Class',palette='Dark2')

# %% [markdown]
# ## Train | Test Split

# %%
X = df.drop('Class',axis=1)
y = df['Class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# # Decision Tree Classifier
#
# ## Default Hyperparameters

# %%
model = DecisionTreeClassifier()
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
base_pred = model.predict(X_test)

# %% [markdown]
# ## Evaluation

# %%
y_pred = model.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
cmd = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)

cmd.plot()
plt.show()

# %%
print(classification_report(y_test,base_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.81      0.81       140
#            1       0.80      0.81      0.80       130
#
#     accuracy                           0.81       270
#    macro avg       0.81      0.81      0.81       270
# weighted avg       0.81      0.81      0.81       270

# %%
model.feature_importances_
# Out:
# array([0.03012561, 0.63016802, 0.05561507, 0.08636349, 0.03097453,
#        0.0904589 , 0.07629437])

# %%
pd.DataFrame(index=df.drop('Class', axis=1).columns,data=model.feature_importances_,columns=['Feature Importance'])
# Out:
#                  Feature Importance
# Area                       0.030126
# MajorAxisLength            0.630168
# MinorAxisLength            0.055615
# Eccentricity               0.086363
# ConvexArea                 0.030975
# Extent                     0.090459
# Perimeter                  0.076294

# %% [markdown]
# ## Visualize the Tree

# %%
plt.figure(figsize=(12,8))
plot_tree(model)
# Out:
# [Text(0.6369257950530035, 0.9642857142857143, 'x[1] <= 422.423\ngini = 0.5\nsamples = 630\nvalue = [310, 320]'),
#  Text(0.4452296819787986, 0.8928571428571429, 'x[6] <= 1127.743\ngini = 0.271\nsamples = 334\nvalue = [280, 54]'),
#  Text(0.35335689045936397, 0.8214285714285714, 'x[3] <= 0.87\ngini = 0.22\nsamples = 302\nvalue = [264, 38]'),
#  Text(0.26855123674911663, 0.75, 'x[0] <= 60551.0\ngini = 0.199\nsamples = 295\nvalue = [262, 33]'),
#  Text(0.1413427561837456, 0.6785714285714286, 'x[5] <= 0.827\ngini = 0.11\nsamples = 154\nvalue = [145, 9]'),
#  Text(0.127208480565371, 0.6071428571428571, 'x[6] <= 917.732\ngini = 0.099\nsamples = 153\nvalue = [145, 8]'),
#  Text(0.08480565371024736, 0.5357142857142857, 'x[3] <= 0.734\ngini = 0.056\nsamples = 104\nvalue = [101, 3]'),
#  Text(0.0706713780918728, 0.4642857142857143, 'x[3] <= 0.733\ngini = 0.113\nsamples = 50\nvalue = [47, 3]'),
#  Text(0.05653710247349823, 0.39285714285714285, 'x[5] <= 0.671\ngini = 0.078\nsamples = 49\nvalue = [47.0, 2.0]'),
#  Text(0.028268551236749116, 0.32142857142857145, 'x[5] <= 0.666\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.014134275618374558, 0.25, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.04240282685512368, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08480565371024736, 0.32142857142857145, 'x[2] <= 194.922\ngini = 0.045\nsamples = 43\nvalue = [42, 1]'),
#  Text(0.0706713780918728, 0.25, 'x[1] <= 272.917\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.05653710247349823, 0.17857142857142858, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.08480565371024736, 0.17857142857142858, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0989399293286219, 0.25, 'gini = 0.0\nsamples = 36\nvalue = [36, 0]'),
#  Text(0.08480565371024736, 0.39285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0989399293286219, 0.4642857142857143, 'gini = 0.0\nsamples = 54\nvalue = [54, 0]'),
#  Text(0.1696113074204947, 0.5357142857142857, 'x[4] <= 56041.0\ngini = 0.183\nsamples = 49\nvalue = [44, 5]'),
#  Text(0.1413427561837456, 0.4642857142857143, 'x[4] <= 55983.0\ngini = 0.463\nsamples = 11\nvalue = [7, 4]'),
#  Text(0.127208480565371, 0.39285714285714285, 'x[6] <= 923.717\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.11307420494699646, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1413427561837456, 0.32142857142857145, 'x[2] <= 210.573\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.127208480565371, 0.25, 'x[0] <= 51516.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.11307420494699646, 0.17857142857142858, 'x[3] <= 0.812\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.0989399293286219, 0.10714285714285714, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.127208480565371, 0.10714285714285714, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1413427561837456, 0.17857142857142858, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.15547703180212014, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15547703180212014, 0.39285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1978798586572438, 0.4642857142857143, 'x[2] <= 204.082\ngini = 0.051\nsamples = 38\nvalue = [37, 1]'),
#  Text(0.18374558303886926, 0.39285714285714285, 'x[2] <= 202.71\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.1696113074204947, 0.32142857142857145, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.1978798586572438, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.21201413427561838, 0.39285714285714285, 'gini = 0.0\nsamples = 31\nvalue = [31, 0]'),
#  Text(0.15547703180212014, 0.6071428571428571, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3957597173144876, 0.6785714285714286, 'x[2] <= 235.495\ngini = 0.282\nsamples = 141\nvalue = [117, 24]'),
#  Text(0.31095406360424027, 0.6071428571428571, 'x[2] <= 234.239\ngini = 0.458\nsamples = 45\nvalue = [29.0, 16.0]'),
#  Text(0.2968197879858657, 0.5357142857142857, 'x[0] <= 61643.0\ngini = 0.427\nsamples = 42\nvalue = [29, 13]'),
#  Text(0.254416961130742, 0.4642857142857143, 'x[2] <= 226.011\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.24028268551236748, 0.39285714285714285, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.26855123674911663, 0.39285714285714285, 'x[5] <= 0.727\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.254416961130742, 0.32142857142857145, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.2826855123674912, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3392226148409894, 0.4642857142857143, 'x[6] <= 1098.26\ngini = 0.353\nsamples = 35\nvalue = [27, 8]'),
#  Text(0.3250883392226148, 0.39285714285714285, 'x[5] <= 0.781\ngini = 0.298\nsamples = 33\nvalue = [27, 6]'),
#  Text(0.31095406360424027, 0.32142857142857145, 'x[0] <= 69448.0\ngini = 0.264\nsamples = 32\nvalue = [27, 5]'),
#  Text(0.26855123674911663, 0.25, 'x[5] <= 0.702\ngini = 0.147\nsamples = 25\nvalue = [23, 2]'),
#  Text(0.254416961130742, 0.17857142857142858, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.2826855123674912, 0.17857142857142858, 'x[5] <= 0.722\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.26855123674911663, 0.10714285714285714, 'x[6] <= 993.023\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.254416961130742, 0.03571428571428571, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2826855123674912, 0.03571428571428571, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2968197879858657, 0.10714285714285714, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.35335689045936397, 0.25, 'x[1] <= 408.763\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.3392226148409894, 0.17857142857142858, 'x[6] <= 1058.686\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.3250883392226148, 0.10714285714285714, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.35335689045936397, 0.10714285714285714, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3674911660777385, 0.17857142857142858, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3392226148409894, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.35335689045936397, 0.39285714285714285, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3250883392226148, 0.5357142857142857, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.48056537102473496, 0.6071428571428571, 'x[5] <= 0.701\ngini = 0.153\nsamples = 96\nvalue = [88, 8]'),
#  Text(0.42402826855123676, 0.5357142857142857, 'x[3] <= 0.705\ngini = 0.346\nsamples = 27\nvalue = [21, 6]'),
#  Text(0.3957597173144876, 0.4642857142857143, 'x[5] <= 0.667\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.38162544169611307, 0.39285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4098939929328622, 0.39285714285714285, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.45229681978798586, 0.4642857142857143, 'x[1] <= 342.924\ngini = 0.227\nsamples = 23\nvalue = [20, 3]'),
#  Text(0.4381625441696113, 0.39285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4664310954063604, 0.39285714285714285, 'x[2] <= 238.003\ngini = 0.165\nsamples = 22\nvalue = [20, 2]'),
#  Text(0.4381625441696113, 0.32142857142857145, 'x[2] <= 236.078\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.42402826855123676, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.45229681978798586, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.49469964664310956, 0.32142857142857145, 'x[5] <= 0.67\ngini = 0.1\nsamples = 19\nvalue = [18, 1]'),
#  Text(0.48056537102473496, 0.25, 'x[5] <= 0.668\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.4664310954063604, 0.17857142857142858, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.49469964664310956, 0.17857142857142858, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.508833922261484, 0.25, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.5371024734982333, 0.5357142857142857, 'x[4] <= 64895.0\ngini = 0.056\nsamples = 69\nvalue = [67, 2]'),
#  Text(0.508833922261484, 0.4642857142857143, 'x[5] <= 0.728\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.49469964664310956, 0.39285714285714285, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5229681978798587, 0.39285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5653710247349824, 0.4642857142857143, 'x[5] <= 0.713\ngini = 0.03\nsamples = 66\nvalue = [65, 1]'),
#  Text(0.5512367491166078, 0.39285714285714285, 'x[5] <= 0.712\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.5371024734982333, 0.32142857142857145, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.5653710247349824, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5795053003533569, 0.39285714285714285, 'gini = 0.0\nsamples = 54\nvalue = [54, 0]'),
#  Text(0.4381625441696113, 0.75, 'x[3] <= 0.889\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.42402826855123676, 0.6785714285714286, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.45229681978798586, 0.6785714285714286, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5371024734982333, 0.8214285714285714, 'x[5] <= 0.681\ngini = 0.5\nsamples = 32\nvalue = [16, 16]'),
#  Text(0.5229681978798587, 0.75, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.5512367491166078, 0.75, 'x[3] <= 0.654\ngini = 0.444\nsamples = 24\nvalue = [16, 8]'),
#  Text(0.5229681978798587, 0.6785714285714286, 'x[5] <= 0.739\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.508833922261484, 0.6071428571428571, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.5371024734982333, 0.6071428571428571, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5795053003533569, 0.6785714285714286, 'x[4] <= 92440.0\ngini = 0.291\nsamples = 17\nvalue = [14, 3]'),
#  Text(0.5653710247349824, 0.6071428571428571, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.5936395759717314, 0.6071428571428571, 'x[5] <= 0.723\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.5795053003533569, 0.5357142857142857, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.607773851590106, 0.5357142857142857, 'x[3] <= 0.671\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.5936395759717314, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6219081272084805, 0.4642857142857143, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8286219081272085, 0.8928571428571429, 'x[1] <= 452.894\ngini = 0.182\nsamples = 296\nvalue = [30, 266]'),
#  Text(0.7879858657243817, 0.8214285714285714, 'x[1] <= 451.177\ngini = 0.46\nsamples = 64\nvalue = [23, 41]'),
#  Text(0.773851590106007, 0.75, 'x[4] <= 96045.0\ngini = 0.441\nsamples = 61\nvalue = [20, 41]'),
#  Text(0.7597173144876325, 0.6785714285714286, 'x[0] <= 87437.0\ngini = 0.477\nsamples = 51\nvalue = [20.0, 31.0]'),
#  Text(0.7137809187279152, 0.6071428571428571, 'x[3] <= 0.859\ngini = 0.42\nsamples = 40\nvalue = [12, 28]'),
#  Text(0.6996466431095406, 0.5357142857142857, 'x[3] <= 0.844\ngini = 0.469\nsamples = 32\nvalue = [12, 20]'),
#  Text(0.6501766784452296, 0.4642857142857143, 'x[1] <= 441.132\ngini = 0.351\nsamples = 22\nvalue = [5, 17]'),
#  Text(0.6219081272084805, 0.39285714285714285, 'x[1] <= 425.134\ngini = 0.266\nsamples = 19\nvalue = [3, 16]'),
#  Text(0.607773851590106, 0.32142857142857145, 'x[4] <= 84905.5\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.5936395759717314, 0.25, 'x[6] <= 1107.293\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.5795053003533569, 0.17857142857142858, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.607773851590106, 0.17857142857142858, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.6219081272084805, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6360424028268551, 0.32142857142857145, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.6784452296819788, 0.39285714285714285, 'x[3] <= 0.833\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6643109540636042, 0.32142857142857145, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6925795053003534, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7491166077738516, 0.4642857142857143, 'x[1] <= 449.968\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.734982332155477, 0.39285714285714285, 'x[6] <= 1102.082\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.7208480565371025, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7491166077738516, 0.32142857142857145, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.7632508833922261, 0.39285714285714285, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7279151943462897, 0.5357142857142857, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.8056537102473498, 0.6071428571428571, 'x[3] <= 0.777\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.7915194346289752, 0.5357142857142857, 'x[6] <= 1180.792\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.7773851590106007, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8056537102473498, 0.4642857142857143, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8197879858657244, 0.5357142857142857, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.7879858657243817, 0.6785714285714286, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.8021201413427562, 0.75, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8692579505300353, 0.8214285714285714, 'x[6] <= 1196.067\ngini = 0.059\nsamples = 232\nvalue = [7, 225]'),
#  Text(0.8303886925795053, 0.75, 'x[2] <= 237.851\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.8162544169611308, 0.6785714285714286, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.8445229681978799, 0.6785714285714286, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9081272084805654, 0.75, 'x[5] <= 0.473\ngini = 0.043\nsamples = 225\nvalue = [5, 220]'),
#  Text(0.872791519434629, 0.6785714285714286, 'x[5] <= 0.417\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8586572438162544, 0.6071428571428571, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8869257950530035, 0.6071428571428571, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9434628975265018, 0.6785714285714286, 'x[1] <= 463.845\ngini = 0.035\nsamples = 223\nvalue = [4, 219]'),
#  Text(0.9151943462897526, 0.6071428571428571, 'x[1] <= 462.932\ngini = 0.245\nsamples = 14\nvalue = [2, 12]'),
#  Text(0.901060070671378, 0.5357142857142857, 'x[1] <= 456.177\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.8869257950530035, 0.4642857142857143, 'x[1] <= 455.789\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.872791519434629, 0.39285714285714285, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.901060070671378, 0.39285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9151943462897526, 0.4642857142857143, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.9293286219081273, 0.5357142857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9717314487632509, 0.6071428571428571, 'x[6] <= 1341.957\ngini = 0.019\nsamples = 209\nvalue = [2, 207]'),
#  Text(0.9575971731448764, 0.5357142857142857, 'x[6] <= 1339.997\ngini = 0.063\nsamples = 61\nvalue = [2, 59]'),
#  Text(0.9434628975265018, 0.4642857142857143, 'x[2] <= 297.87\ngini = 0.033\nsamples = 60\nvalue = [1, 59]'),
#  Text(0.9293286219081273, 0.39285714285714285, 'gini = 0.0\nsamples = 57\nvalue = [0, 57]'),
#  Text(0.9575971731448764, 0.39285714285714285, 'x[6] <= 1304.855\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.9434628975265018, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9717314487632509, 0.32142857142857145, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9717314487632509, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9858657243816255, 0.5357142857142857, 'gini = 0.0\nsamples = 148\nvalue = [0, 148]')]

# %%
plt.figure(figsize=(12,8),dpi=150)
plot_tree(model,filled=True,feature_names=df.drop('Class', axis=1).columns,);

# %% [markdown]
# ## Reporting Model Results

# %%
def report_model(model):
    model_preds = model.predict(X_test)
    print(classification_report(y_test,model_preds))
    print('\n')
    plt.figure(figsize=(12,8),dpi=150)
    plot_tree(model,filled=True,feature_names=df.drop('Class', axis=1).columns,);

# %% [markdown]
# ## Understanding Hyperparameters
#
# ### Max Depth

# %%
pruned_tree = DecisionTreeClassifier(max_depth=2)
pruned_tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
report_model(pruned_tree)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.92      0.87       140
#            1       0.90      0.79      0.84       130
#
#     accuracy                           0.86       270
#    macro avg       0.87      0.86      0.86       270
# weighted avg       0.86      0.86      0.86       270

# %% [markdown]
# ## Max Leaf Nodes

# %%
pruned_tree = DecisionTreeClassifier(max_leaf_nodes=3)
pruned_tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=3)

# %%
report_model(pruned_tree)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.92      0.87       140
#            1       0.90      0.79      0.84       130
#
#     accuracy                           0.86       270
#    macro avg       0.87      0.86      0.86       270
# weighted avg       0.86      0.86      0.86       270

# %% [markdown]
# ## Criterion

# %%
entropy_tree = DecisionTreeClassifier(criterion='entropy')
entropy_tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
report_model(entropy_tree)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.80      0.80       140
#            1       0.78      0.78      0.78       130
#
#     accuracy                           0.79       270
#    macro avg       0.79      0.79      0.79       270
# weighted avg       0.79      0.79      0.79       270
